# %% [markdown]
# # QVerse — Introduction to Quantum Computing & Programming
#         ## Week 16: Capstone Sprint II — Validate, Explain, and Present
#
#         **Level:** Beginner
#         **Recommended study time:** 2–4 hours
#         **Prerequisites:** Weeks 1–15
#
#         ### Learning objectives
#         - Validate expected versus observed behavior.
# - Improve reproducibility.
# - Communicate limitations honestly.
# - Prepare a concise technical presentation.
#
#         ---
#         **How to use this notebook**
#
#         1. Read the short theory sections.
#         2. Make a prediction before running each guided experiment.
#         3. Run and modify the code.
#         4. Complete every **TODO** exercise.
#         5. Finish the reflection section in your own words.
#
#         The goal is not to memorize syntax. The goal is to connect **quantum idea → circuit → result → explanation**.

# %%
# Run this only if your environment does not have the required packages.
# In a terminal, the preferred setup is:
# python -m pip install "qiskit[visualization]>=2.5" matplotlib numpy

# In a fresh Colab notebook you can instead uncomment:
# %pip install "qiskit[visualization]>=2.5" matplotlib numpy -q

# %% [markdown]
# ## 1. Final deliverable
#
# By the end of this notebook, your repository should contain:
# - a reproducible notebook or Python package;
# - clear circuit diagrams;
# - labeled results;
# - interpretation below important outputs;
# - a concise README;
# - dependency/setup instructions;
# - a 5–8 minute presentation.

# %% [markdown]
# ## 2. Reproducibility audit

# %%
import sys
import platform

print("Python:", sys.version)
print("Platform:", platform.platform())

try:
    import qiskit
    print("Qiskit:", qiskit.__version__)
except Exception as exc:
    print("Qiskit version unavailable:", exc)

# %% [markdown]
# Check all that apply:
#
# - [ ] A new student can identify the entry point.
# - [ ] Installation instructions are explicit.
# - [ ] Random seeds are fixed where reproducibility is useful.
# - [ ] Shot counts are recorded.
# - [ ] Hardware/backend information is recorded when relevant.
# - [ ] Every important plot has labels.
# - [ ] Circuit bit ordering is explained when relevant.
# - [ ] Expected and observed results are both stated.

# %% [markdown]
# ## 3. Final validation experiment

# %%
# TODO:
# Run the final version of your experiment here.
# Prefer a compact cell that another person can rerun easily.

# %% [markdown]
# ## 4. Quantitative comparison

# %%
# TODO:
# Compute at least one meaningful metric.
#
# Examples:
# - algorithm success probability;
# - state fidelity;
# - expectation-value error;
# - fraction of forbidden/undesired outcomes;
# - circuit depth / two-qubit gate count;
# - deviation from an ideal probability distribution.

# %% [markdown]
# ## 5. Expected vs observed
#
# **Expected:**
# TODO
#
# **Observed:**
# TODO
#
# **Agreement/disagreement:**
# TODO
#
# **Most important limitation:**
# TODO

# %% [markdown]
# ## 6. Peer-review rubric
#
# Score each category from 1 (weak) to 5 (excellent).
#
# | Category | Score | Comment |
# |---|---:|---|
# | Correctness | TODO | TODO |
# | Reproducibility | TODO | TODO |
# | Quantum-concept understanding | TODO | TODO |
# | Experimental reasoning | TODO | TODO |
# | Code quality | TODO | TODO |
# | Communication | TODO | TODO |

# %% [markdown]
# ## 7. Presentation structure
#
# A concise 5–8 minute presentation can use:
#
# 1. **Problem:** What did you investigate?
# 2. **Quantum idea:** What concept makes the project quantum?
# 3. **Circuit/workflow:** Show the minimum diagram needed.
# 4. **Prediction:** What did you expect?
# 5. **Result:** Show one strong plot/table.
# 6. **Interpretation:** Why did it happen?
# 7. **Limitations:** What does your result *not* prove?
# 8. **Extension:** What would you do next?

# %% [markdown]
# ## 8. Final technical summary
#
# Complete this in approximately 150–250 words.
#
# **What is genuinely quantum about this project?**
# TODO
#
# **What did the experiment demonstrate?**
# TODO
#
# **What are the main limitations?**
# TODO

# %% [markdown]
# ## Core exercises
# 1. Run a peer review using the rubric.
# 2. Fix at least one reproducibility issue.
# 3. Fix at least one explanation/communication issue.
# 4. Prepare one slide or section answering: 'What is genuinely quantum about this project?'

# %%
# TODO: Write your solutions here.
# Add extra code cells when useful.

# %% [markdown]
# ## Optional stretch challenge
# Add one extension not explicitly taught in the course, but keep the base project understandable to a Week-8 student.

# %%
# OPTIONAL TODO: Attempt the stretch challenge here.

# %% [markdown]
# ## Weekly reflection
# - What evidence supports your main conclusion?
# - Which assumption most limits the project?
# - Could another student reproduce your result from the repository alone?

# %% [markdown]
# ## Submission checklist
# - [ ] I made at least one prediction before executing a circuit.
# - [ ] All guided examples run.
# - [ ] I completed the core exercises.
# - [ ] I explained the important output rather than only displaying it.
# - [ ] My notebook is readable from top to bottom.
