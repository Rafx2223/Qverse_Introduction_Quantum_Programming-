# %% [markdown]
# # QVerse — Introduction to Quantum Computing & Programming
#         ## Week 15: Capstone Sprint I — Build a Reproducible Prototype
#
#         **Level:** Beginner
#         **Recommended study time:** 2–4 hours
#         **Prerequisites:** Weeks 1–14
#
#         ### Learning objectives
#         - Turn a narrow question into a quantum experiment.
# - Define a hypothesis and success metric before coding.
# - Create a minimum working implementation.
# - Add sanity tests and a baseline.
#
#         ---
#         **How to use this notebook**
#
#         1. Read the short theory sections.
#         2. Make a prediction before running each guided experiment.
#         3. Run and modify the code.
#         4. Complete every **TODO** exercise.
#         5. Finish the reflection section in your own words.
#
#         The goal is not to memorize syntax. The goal is to connect **quantum idea → circuit → result → explanation**.

# %%
# Run this only if your environment does not have the required packages.
# In a terminal, the preferred setup is:
# python -m pip install "qiskit[visualization]>=2.5" matplotlib numpy

# In a fresh Colab notebook you can instead uncomment:
# %pip install "qiskit[visualization]>=2.5" matplotlib numpy -q

# %% [markdown]
# ## 1. Capstone rules
#
# Work individually or in teams of 2–4. A strong beginner project is **small, testable, reproducible, and explainable**.
#
# Recommended project menu:
# - quantum random-number generator;
# - Bell-correlation explorer;
# - teleportation demonstrator;
# - Grover puzzle solver;
# - tiny variational/VQE-style demonstrator;
# - noise-aware circuit comparison;
# - superdense-coding or protocol demo;
# - mini reusable algorithm library.
#
# Avoid claiming "quantum advantage" unless you have actually demonstrated it under a defensible comparison.

# %% [markdown]
# ## 2. Project proposal
#
# Fill this in **before** building the final implementation.
#
# **Project title:**
# TODO
#
# **Research/engineering question:**
# TODO
#
# **Quantum concept used:**
# TODO
#
# **Expected result / hypothesis:**
# TODO
#
# **Primary success metric:**
# TODO
#
# **Baseline:**
# TODO
#
# **Known limitations:**
# TODO

# %% [markdown]
# ## 3. Environment record

# %%
import sys
import platform

print("Python:", sys.version)
print("Platform:", platform.platform())

try:
    import qiskit
    print("Qiskit:", qiskit.__version__)
except Exception as exc:
    print("Qiskit version unavailable:", exc)

# %% [markdown]
# ## 4. Minimum working circuit

# %%
# TODO:
# Build the smallest circuit that tests the central idea of your project.
#
# Example skeleton:
#
# from qiskit import QuantumCircuit
# qc = QuantumCircuit(...)
# ...
# qc.draw("mpl")

# %% [markdown]
# ## 5. Prediction before execution

# %% [markdown]
# Write the expected result **before** executing the experiment.
#
# TODO: What outcomes/distribution/expectation value do you expect, and why?

# %%
# TODO: Execute your baseline experiment here.

# %% [markdown]
# ## 6. Sanity tests

# %%
# TODO: Add at least one sanity test.
#
# Examples:
# - verify a known basis-state case;
# - compare two statevectors with Statevector.equiv;
# - assert probabilities sum to 1;
# - verify a circuit followed by its inverse restores the input;
# - verify an algorithm succeeds on a trivial instance.

# %% [markdown]
# ## 7. Baseline result

# %%
# TODO: Generate and store at least one baseline result.
# Use a clearly labeled table, dictionary, or plot.

# %% [markdown]
# ## 8. Interpretation

# %% [markdown]
# **What happened?**
# TODO
#
# **Did it match the hypothesis?**
# TODO
#
# **What is still missing before Week 16?**
# TODO

# %% [markdown]
# ## Core exercises
# 1. Write a one-sentence research question.
# 2. Create the minimum working circuit.
# 3. Add at least one automated or explicit sanity test.
# 4. Record one baseline result and interpret it.

# %%
# TODO: Write your solutions here.
# Add extra code cells when useful.

# %% [markdown]
# ## Optional stretch challenge
# Run the same project through both an ideal path and a noisy/hardware path, then define one quantitative comparison metric.

# %%
# OPTIONAL TODO: Attempt the stretch challenge here.

# %% [markdown]
# ## Weekly reflection
# - Is the project small enough to explain in five minutes?
# - What result would falsify or challenge your hypothesis?
# - What is genuinely quantum about the implementation?

# %% [markdown]
# ## Submission checklist
# - [ ] I made at least one prediction before executing a circuit.
# - [ ] All guided examples run.
# - [ ] I completed the core exercises.
# - [ ] I explained the important output rather than only displaying it.
# - [ ] My notebook is readable from top to bottom.
